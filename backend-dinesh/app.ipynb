# %%
import os
from dotenv import load_dotenv

load_dotenv()

SUPABASE_URL = os.getenv("SUPABASE_URL")
SUPABASE_ANON_KEY = os.getenv("SUPABASE_ANON_KEY")
SUPABASE_SERVICE_KEY = os.getenv("SUPABASE_SERVICE_KEY")

# %%
print("Supabase URL:", SUPABASE_URL)
print("Supabase Anon Key:", SUPABASE_ANON_KEY)
print("Supabase Service Key:", SUPABASE_SERVICE_KEY)
# Out:
# Supabase URL: https://zqldlejygeyytslruovn.supabase.co
# Supabase Anon Key: eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6InpxbGRsZWp5Z2V5eXRzbHJ1b3ZuIiwicm9sZSI6ImFub24iLCJpYXQiOjE3NjI1MDg3MTQsImV4cCI6MjA3ODA4NDcxNH0.hOR_PG6VJGcOpx0de-K0mCbfJ3MXxPm3FPKHESatHK4
# Supabase Service Key: eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6InpxbGRsZWp5Z2V5eXRzbHJ1b3ZuIiwicm9sZSI6InNlcnZpY2Vfcm9sZSIsImlhdCI6MTc2MjUwODcxNCwiZXhwIjoyMDc4MDg0NzE0fQ.Z8BvLqqqIqBdWNuhi3jr2-PpW23bFjGahlSvGMdDAnI
